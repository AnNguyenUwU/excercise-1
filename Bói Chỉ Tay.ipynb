# %% [markdown]
# <a href="https://colab.research.google.com/github/AnNguyenUwU/excercise-1/blob/main/B%C3%B3i%20Ch%E1%BB%89%20Tay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np
import os

data_dir = '/content/drive/MyDrive/Palm dataset'

BATCH_SIZE = 32
IMG_HEIGHT = 150
IMG_WIDTH = 150

print("Đang tải và chia tập dữ liệu huấn luyện (Train - 80%)...")
train_dataset = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE)

print("Đang tải và chia tập dữ liệu kiểm định (Validation - 20%)...")
val_dataset = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE)

class_names = train_dataset.class_names
print("Các nhãn bói chỉ tay được tìm thấy:", class_names)

AUTOTUNE = tf.data.AUTOTUNE
train_dataset = train_dataset.shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.cache().prefetch(buffer_size=AUTOTUNE)


num_classes = len(class_names)

model = models.Sequential([
  layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
  layers.Rescaling(1./255),

  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),

  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),

  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),

  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dropout(0.5),
  layers.Dense(num_classes, activation='softmax' if num_classes > 2 else 'sigmoid')
])

loss_function = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False) if num_classes > 2 else tf.keras.losses.BinaryCrossentropy()

model.compile(optimizer='adam',
              loss=loss_function,
              metrics=['accuracy'])

model.summary()


history = model.fit(
  train_dataset,
  validation_data=val_dataset,
  epochs=40
)

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(40)
# Out:
# Đang tải và chia tập dữ liệu huấn luyện (Train - 80%)...
# Found 3665 files belonging to 6 classes.
# Using 2932 files for training.
# Đang tải và chia tập dữ liệu kiểm định (Validation - 20%)...
# Found 3665 files belonging to 6 classes.
# Using 733 files for validation.
# Các nhãn bói chỉ tay được tìm thấy: ['Sinh đạo dài', 'Sinh đạo ngắn', 'Tâm đạo dài', 'Tâm đạo ngắn', 'Trí đạo dài', 'Trí đạo ngắn']
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 150, 150, 16)   │           448 │
# ...

# %%
# !pip install gradio

# %%
import gradio as gr
import cv2
import numpy as np
import tensorflow as tf
import unicodedata

DICT_GIAI_MA = {
    "Sinh đạo dài": "🌟 **Ý nghĩa:** Bạn có sức khỏe dồi dào, sức sống mãnh liệt và khả năng hồi phục tốt. Cuộc đời ít biến cố lớn về sức khỏe.",
    "Sinh đạo ngắn": "⚠️ **Ý nghĩa:** Không hẳn là thọ ngắn, nhưng cho thấy sức khỏe đôi khi không ổn định. Bạn nên chú trọng rèn luyện thể thao và lối sống lành mạnh.",
    "Trí đạo dài": "🧠 **Ý nghĩa:** Bạn là người thực tế, có lối tư duy logic, rạch ròi và rất quyết đoán trong công việc.",
    "Trí đạo ngắn": "🧠 **Ý nghĩa:** Bạn là người có thiên hướng hành động bộc phát, bản năng.",
    "Tâm đạo dài": "❤️ **Ý nghĩa:** Bạn là người giàu tình cảm, sâu sắc và luôn quan tâm đến người khác, đôi khi dễ bị cảm xúc chi phối.",
    "Tâm đạo ngắn": "⚠️ **Ý nghĩa:** Đường tình duyên gặp nhiều khó khăn trắc trở, khó hòa đồng với mọi người.",
}

DICT_GIAI_MA_CHUAN = {
    unicodedata.normalize('NFC', k).strip().lower(): v
    for k, v in DICT_GIAI_MA.items()
}

def predict_and_explain(img):
    if img is None:
        return None, "Vui lòng tải ảnh lên"

    img_resized = cv2.resize(img, (IMG_WIDTH, IMG_HEIGHT))
    img_expanded = np.expand_dims(img_resized, axis=0)

    predictions = model.predict(img_expanded, verbose=0)
    score = tf.nn.softmax(predictions[0]).numpy()

    result_dict = {class_names[i]: float(score[i]) for i in range(num_classes)}

    sorted_indices = np.argsort(score)[::-1]

    top_k = min(3, len(sorted_indices))

    explanation_md = ""
    for rank in range(top_k):
        idx = sorted_indices[rank]
        label_name = class_names[idx]
        confidence = score[idx] * 100

        label_tra_cuu = unicodedata.normalize('NFC', label_name).strip().lower()
        y_nghia = DICT_GIAI_MA_CHUAN.get(label_tra_cuu, "Chưa có thông tin giải mã cho đặc điểm này.")

        explanation_md += f"### 📌 Đặc điểm {rank+1}: {label_name} \n{y_nghia}\n\n"

    return result_dict, explanation_md

with gr.Blocks() as demo:
    gr.Markdown("# 🖐️ AI XEM CHỈ TAY")
    gr.Markdown("Tải ảnh bàn tay của bạn lên để xem AI giải mã vận mệnh.")

    with gr.Row():
        with gr.Column():
            input_img = gr.Image(sources=["upload"], label="Ảnh bàn tay")
            btn = gr.Button("🔮 BẮT ĐẦU GIẢI MÃ", variant="primary")

        with gr.Column():
            output_label = gr.Label(num_top_classes=3, label="Phân tích AI")

    gr.Markdown("---")
    gr.Markdown("## 📖 GIẢI MÃ CHI TIẾT CÁC ĐƯỜNG CHỈ TAY")
    output_text = gr.Markdown("Kết quả giải mã của cả 3 đường chỉ tay sẽ xuất hiện tại đây...")

    btn.click(fn=predict_and_explain, inputs=input_img, outputs=[output_label, output_text])

demo.launch(share=True, debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://fda64f2fc25c23f386.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://fda64f2fc25c23f386.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gradio/route_utils.py", line 354, in call_process_api
# ...
